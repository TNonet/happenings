# %%
from happenings import (function_event, convolve, buffer, scale, interp)
from happenings import MONTH, DAYS_OF_WEEK, DAY_OF_MONTH

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import math

# %% [markdown]
# # Events interface natively with numpy

# %%
days = pd.date_range(freq='D', start='1/1/2020', end='12/31/2020')
plt.plot(days, MONTH.sample_from(days))
plt.show()

# %%
square_month = np.square(MONTH.astype(float))
square_month
# Out:
# DerivedEvent(name='square(<lambda>(Month)_0)_1', dtype=<class 'numpy.float64'>, name_factory=<class 'happenings.core.DefaultNameFactory'>)

# %%
plt.plot(days, (square_month*DAY_OF_MONTH).sample_from(days))
plt.show()

# %%
plt.plot(days, square_month.sample_from(days)*)
plt.show()

# %%
np.dot(square_month, square_month).sample_from(days).plot()
plt.show()

# %% [markdown]
# # Events can interact with each other!

# %%
phase = interp(df['time'].to_numpy(),
               df['phase'].to_numpy(), 
               period=np.timedelta64(datetime.timedelta(days=29.5)))

days = pd.date_range(freq='D', start='1/1/2020', end='12/31/2020')

plt.plot(days, phase.sample_from(days))
plt.plot(days, np.sin(2*np.pi*phase).sample_from(days))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9353ceb55c2f> in <module>
# ----> 1 phase = interp(df['time'].to_numpy(),
#       2                df['phase'].to_numpy(),
#       3                period=np.timedelta64(datetime.timedelta(days=29.5)))
#       4
#       5 days = pd.date_range(freq='D', start='1/1/2020', end='12/31/2020')
#
# NameError: name 'df' is not defined

# %%
plt.plot(pd.date_range(freq='D', start='1/1/2020', end='3/1/2020'), values)
plt.plot(pd.date_range(freq='D', start='1/1/2020', end='12/31/2020'), np.sin(2*np.pi*values))
plt.show()

# %%
plt.plot(np.sin(2 * np.pi * np.tile(np.linspace(0, .98), 2)))
plt.show()

# %%
df = get_percipitation_info()

# %%
plt.plot(df['time'], df['hourlyPrecipRate'])
plt.title("Hourly Percipitation Rate mm/hr")
plt.show()
